# %%
import pandas as pd,numpy as np

# %%
hier_ind_ser=pd.Series(np.random.rand(8),index=[['white','white','white','blue','blue','red','red','red'],['up','down',
                                'centre','up','centre','up','down','centre']])

# %%
hier_ind_ser
# Out:
# white  up        0.709044
#        down      0.719720
#        centre    0.204231
# blue   up        0.904270
#        centre    0.726524
# red    up        0.173084
#        down      0.891740
#        centre    0.892260
# dtype: float64

# %%
dic={'name':['alisa','bobby','cathrine','alisa','bobby','cathrine','alsia','bobby','cathrine','alisa','bobby','cathrine'],
    'data':['sem1','sem1','sem1','sem1','sem1','sem1','sem2','sem2','sem2','sem2','sem2','sem2'],
    'subject':['math','math','math','science','science','science','math','math','math','science','science','science'],
    'score':[62,47,55,74,31,77,85,63,42,67,89,81]}

# %%
hier_ind_df=pd.DataFrame(dic,)

# %%
hier_ind_df
# Out:
#         name  data  subject  score
# 0      alisa  sem1     math     62
# 1      bobby  sem1     math     47
# 2   cathrine  sem1     math     55
# 3      alisa  sem1  science     74
# 4      bobby  sem1  science     31
# 5   cathrine  sem1  science     77
# 6      alsia  sem2     math     85
# 7      bobby  sem2     math     63
# 8   cathrine  sem2     math     42
# 9      alisa  sem2  science     67
# 10     bobby  sem2  science     89
# 11  cathrine  sem2  science     81

# %%
hier_ind_df=hier_ind_df.set_index(['data','subject'])

# %%
hier_ind_df
# Out:
#                   name  score
# data subject
# sem1 math        alisa     62
#      math        bobby     47
#      math     cathrine     55
#      science     alisa     74
#      science     bobby     31
#      science  cathrine     77
# sem2 math        alsia     85
#      math        bobby     63
#      math     cathrine     42
#      science     alisa     67
#      science     bobby     89
#      science  cathrine     81

# %%
hier_ind_df.index
# Out:
# MultiIndex([('sem1',    'math'),
#             ('sem1',    'math'),
#             ('sem1',    'math'),
#             ('sem1', 'science'),
#             ('sem1', 'science'),
#             ('sem1', 'science'),
#             ('sem2',    'math'),
#             ('sem2',    'math'),
#             ('sem2',    'math'),
#             ('sem2', 'science'),
#             ('sem2', 'science'),
#             ('sem2', 'science')],
#            names=['data', 'subject'])

# %%
hier_ind_df.swaplevel('subject','data')
# Out:
#                   name  score
# subject data
# math    sem1     alisa     62
#         sem1     bobby     47
#         sem1  cathrine     55
# science sem1     alisa     74
#         sem1     bobby     31
#         sem1  cathrine     77
# math    sem2     alsia     85
#         sem2     bobby     63
#         sem2  cathrine     42
# science sem2     alisa     67
#         sem2     bobby     89
#         sem2  cathrine     81

# %%
hier_ind_df
# Out:
#                   name  score
# data subject
# sem1 math        alisa     62
#      math        bobby     47
#      math     cathrine     55
#      science     alisa     74
#      science     bobby     31
#      science  cathrine     77
# sem2 math        alsia     85
#      math        bobby     63
#      math     cathrine     42
#      science     alisa     67
#      science     bobby     89
#      science  cathrine     81

# %%
hier_ind_ser
# Out:
# white  up        0.709044
#        down      0.719720
#        centre    0.204231
# blue   up        0.904270
#        centre    0.726524
# red    up        0.173084
#        down      0.891740
#        centre    0.892260
# dtype: float64

# %%
hier_ind_ser.unstack()
# convert hier series to df
# specially hier series
# Out:
#          centre     down        up
# blue   0.726524      NaN  0.904270
# red    0.892260  0.89174  0.173084
# white  0.204231  0.71972  0.709044

# %%
hier_ind_df.stack()
# convert df to series
# Out:
# data  subject
# sem1  math     name        alisa
#                score          62
#                name        bobby
#                score          47
#                name     cathrine
#                score          55
#       science  name        alisa
#                score          74
#                name        bobby
#                score          31
#                name     cathrine
#                score          77
# sem2  math     name        alsia
#                score          85
#                name        bobby
#                score          63
#                name     cathrine
#                score          42
#       science  name        alisa
#                score          67
#                name        bobby
#                score          89
#                name     cathrine
#                score          81
# dtype: object

# %%
df=pd.DataFrame(np.random.randint(4,20,size=(4,5)),columns=['col1','col2','col3','col4','col5'],index=np.arange(4))

# %%
df
# Out:
#    col1  col2  col3  col4  col5
# 0     7    10     9    14    13
# 1    11    17    11    18    10
# 2    11    19     9    11    15
# 3    19     4     5    18    12

# %%
df.stack()
# convert df to  ser
# specially normal df
# Out:
# 0  col1     7
#    col2    10
#    col3     9
#    col4    14
#    col5    13
# 1  col1    11
#    col2    17
#    col3    11
#    col4    18
#    col5    10
# 2  col1    11
#    col2    19
#    col3     9
#    col4    11
#    col5    15
# 3  col1    19
#    col2     4
#    col3     5
#    col4    18
#    col5    12
# dtype: int64

# %%
hier_ind_df.columns
# Out:
# Index(['name', 'score'], dtype='object')

# %%
hier_ind_df.index
# Out:
# MultiIndex([('sem1',    'math'),
#             ('sem1',    'math'),
#             ('sem1',    'math'),
#             ('sem1', 'science'),
#             ('sem1', 'science'),
#             ('sem1', 'science'),
#             ('sem2',    'math'),
#             ('sem2',    'math'),
#             ('sem2',    'math'),
#             ('sem2', 'science'),
#             ('sem2', 'science'),
#             ('sem2', 'science')],
#            names=['data', 'subject'])

# %%
hier_ind_df.index.names
# Out:
# FrozenList(['data', 'subject'])

# %%
hier_ind_df.index.names=['exam','sub']

# %%
hier_ind_df.index.names
# Out:
# FrozenList(['exam', 'sub'])

# %%
hier_ind_df.columns
# Out:
# Index(['name', 'score'], dtype='object')

# %%
hier_ind_df.columns.names=['Name']

# %%
hier_ind_df
# Out:
# Name              name  score
# exam sub
# sem1 math        alisa     62
#      math        bobby     47
#      math     cathrine     55
#      science     alisa     74
#      science     bobby     31
#      science  cathrine     77
# sem2 math        alsia     85
#      math        bobby     63
#      math     cathrine     42
#      science     alisa     67
#      science     bobby     89
#      science  cathrine     81

# %%
df
# Out:
#    col1  col2  col3  col4  col5
# 0     7    10     9    14    13
# 1    11    17    11    18    10
# 2    11    19     9    11    15
# 3    19     4     5    18    12

# %%
df.index.name='INT'

# %%
df.columns.name='COLUMN'

# %%
df
# Out:
# COLUMN  col1  col2  col3  col4  col5
# INT
# 0          7    10     9    14    13
# 1         11    17    11    18    10
# 2         11    19     9    11    15
# 3         19     4     5    18    12

# %%
df.swapaxes(0,1)
# Out:
# INT      0   1   2   3
# COLUMN
# col1     7  11  11  19
# col2    10  17  19   4
# col3     9  11   9   5
# col4    14  18  11  18
# col5    13  10  15  12

# %%
df.sum(axis=0)
# Out:
# COLUMN
# col1    48
# col2    50
# col3    34
# col4    61
# col5    50
# dtype: int64

# %%
df
# Out:
# COLUMN  col1  col2  col3  col4  col5
# INT
# 0          7    10     9    14    13
# 1         11    17    11    18    10
# 2         11    19     9    11    15
# 3         19     4     5    18    12

# %%
df.sum(axis=1)
# Out:
# INT
# 0    53
# 1    67
# 2    65
# 3    58
# dtype: int64

# %%
hier_ind_df.sum(level='exam',numeric_only=True)
# Out:
# /tmp/ipykernel_4289/1618012357.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   hier_ind_df.sum(level='exam',numeric_only=True)
# Name  score
# exam
# sem1    346
# sem2    427

# %%
arr=[[5,3,5,2,1],['A','X','D','R','Q']]
hie_multi=pd.MultiIndex.from_arrays(arr,names=('Number','Code'))

# %%
hie_multi
# Out:
# MultiIndex([(5, 'A'),
#             (3, 'X'),
#             (5, 'D'),
#             (2, 'R'),
#             (1, 'Q')],
#            names=['Number', 'Code'])

# %%
hie_multi.duplicated()
# Out:
# array([False, False, False, False, False])

# %%
df
# Out:
# COLUMN  col1  col2  col3  col4  col5
# INT
# 0          7    10     9    14    13
# 1         11    17    11    18    10
# 2         11    19     9    11    15
# 3         19     4     5    18    12

# %%
df.columns=['A','B','C','D','E']

# %%
df.index=[np.linspace(10,40,4,dtype=int)]

# %%
df
# Out:
#      A   B   C   D   E
# 10   7  10   9  14  13
# 20  11  17  11  18  10
# 30  11  19   9  11  15
# 40  19   4   5  18  12

# %%
df.replace(11,12)
# Out:
#      A   B   C   D   E
# 10   7  10   9  14  13
# 20  12  17  12  18  10
# 30  12  19   9  12  15
# 40  19   4   5  18  12

# %%
df
# Out:
#      A   B   C   D   E
# 10   7  10   9  14  13
# 20  11  17  11  18  10
# 30  11  19   9  11  15
# 40  19   4   5  18  12

# %%
df.replace([19,12,5],df.mean().min()).astype(int)
# Out:
#      A   B   C   D   E
# 10   7  10   9  14  13
# 20  11  17  11  18  10
# 30  11   8   9  11  15
# 40   8   4   8  18   8

# %%
df.replace([7,10],method='bfill')
# Out:
#      A   B   C   D   E
# 10  11  17   9  14  13
# 20  11  17  11  18  15
# 30  11  19   9  11  15
# 40  19   4   5  18  12

# %%
df.replace([7,10],method='ffill')
# Out:
#      A   B   C   D   E
# 10   7  10   9  14  13
# 20  11  17  11  18  13
# 30  11  19   9  11  15
# 40  19   4   5  18  12

# %%
df.replace({'A':11,'E':12},545,inplace=True)

# %%
df
# Out:
#       A   B   C   D    E
# 10    7  10   9  14   13
# 20  545  17  11  18   10
# 30  545  19   9  11   15
# 40   19   4   5  18  545

# %%
hier_ind_df
# Out:
# Name              name  score
# exam sub
# sem1 math        alisa     62
#      math        bobby     47
#      math     cathrine     55
#      science     alisa     74
#      science     bobby     31
#      science  cathrine     77
# sem2 math        alsia     85
#      math        bobby     63
#      math     cathrine     42
#      science     alisa     67
#      science     bobby     89
#      science  cathrine     81

# %%
df=pd.DataFrame({'col1':['a','a','b','a'],'col2':['one','two','two','one'],'col3':np.random.randn(4),
                'col4':np.random.rand(4)})

# %%
np.random.randint(4,10,size=[2,3])
# Out:
# array([[4, 8, 5],
#        [4, 4, 8]])

# %%
df
# Out:
#   col1 col2      col3      col4
# 0    a  one  0.008789  0.146322
# 1    a  two -0.073255  0.831645
# 2    b  two -1.588053  0.988356
# 3    a  one -1.411390  0.470098

# %%
grouped=df['col3'].groupby(df['col2'])

# %%
grouped.describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# col2
# one     2.0 -0.701301  1.004218 -1.411390 -1.056345 -0.701301 -0.346256
# two     2.0 -0.830654  1.071124 -1.588053 -1.209354 -0.830654 -0.451955
#
#            max
# col2
# one   0.008789
# two  -0.073255

# %%
df.groupby('col1').mean()
# Out:
#           col3      col4
# col1
# a    -0.491952  0.482688
# b    -1.588053  0.988356

# %%
df.groupby(['col1','col2']).mean()
# Out:
#                col3      col4
# col1 col2
# a    one  -0.701301  0.308210
#      two  -0.073255  0.831645
# b    two  -1.588053  0.988356

# %%
df.groupby(['col1','col2'])[['col3']].mean()
# Out:
#                col3
# col1 col2
# a    one  -0.701301
#      two  -0.073255
# b    two  -1.588053

# %%
for name ,group in df.groupby('col1'):
    print(name)
    print(group)
# Out:
# a
#   col1 col2      col3      col4
# 0    a  one  0.008789  0.146322
# 1    a  two -0.073255  0.831645
# 3    a  one -1.411390  0.470098
# b
#   col1 col2      col3      col4
# 2    b  two -1.588053  0.988356

# %%
df
# Out:
#   col1 col2      col3      col4
# 0    a  one  0.008789  0.146322
# 1    a  two -0.073255  0.831645
# 2    b  two -1.588053  0.988356
# 3    a  one -1.411390  0.470098

# %%
df2=pd.DataFrame({'col1':['b','a','a','b','a'],'col2':['one','two','one','one','two'],
                 'col3':np.random.randn(5),'col4':np.random.randn(5)})

# %%
df2
# Out:
#   col1 col2      col3      col4
# 0    b  one -1.186421  0.425992
# 1    a  two  1.094391  0.999719
# 2    a  one  1.577937  0.521308
# 3    b  one  0.457513  1.042979
# 4    a  two  0.149436 -0.454700

# %%
df2.rename(columns={'col2':'col'},inplace=True)

# %%
df2
# Out:
#   col1  col      col3      col4
# 0    b  one -1.186421  0.425992
# 1    a  two  1.094391  0.999719
# 2    a  one  1.577937  0.521308
# 3    b  one  0.457513  1.042979
# 4    a  two  0.149436 -0.454700

# %%
df
# Out:
#   col1 col2      col3      col4
# 0    a  one  0.008789  0.146322
# 1    a  two -0.073255  0.831645
# 2    b  two -1.588053  0.988356
# 3    a  one -1.411390  0.470098

# %%
pd.merge(df2,df)
# Out:
# Empty DataFrame
# Columns: [col1, col, col3, col4, col2]
# Index: []

# %%
pd.merge(df,df2,on='col1')
# Out:
#    col1 col2    col3_x    col4_x  col    col3_y    col4_y
# 0     a  one  0.008789  0.146322  two  1.094391  0.999719
# 1     a  one  0.008789  0.146322  one  1.577937  0.521308
# 2     a  one  0.008789  0.146322  two  0.149436 -0.454700
# 3     a  two -0.073255  0.831645  two  1.094391  0.999719
# 4     a  two -0.073255  0.831645  one  1.577937  0.521308
# 5     a  two -0.073255  0.831645  two  0.149436 -0.454700
# 6     a  one -1.411390  0.470098  two  1.094391  0.999719
# 7     a  one -1.411390  0.470098  one  1.577937  0.521308
# 8     a  one -1.411390  0.470098  two  0.149436 -0.454700
# 9     b  two -1.588053  0.988356  one -1.186421  0.425992
# 10    b  two -1.588053  0.988356  one  0.457513  1.042979

# %%
pd.merge(df,df2,left_on='col2',right_on='col')
# Out:
#   col1_x col2    col3_x    col4_x col1_y  col    col3_y    col4_y
# 0      a  one  0.008789  0.146322      b  one -1.186421  0.425992
# 1      a  one  0.008789  0.146322      a  one  1.577937  0.521308
# 2      a  one  0.008789  0.146322      b  one  0.457513  1.042979
# 3      a  one -1.411390  0.470098      b  one -1.186421  0.425992
# 4      a  one -1.411390  0.470098      a  one  1.577937  0.521308
# 5      a  one -1.411390  0.470098      b  one  0.457513  1.042979
# 6      a  two -0.073255  0.831645      a  two  1.094391  0.999719
# 7      a  two -0.073255  0.831645      a  two  0.149436 -0.454700
# 8      b  two -1.588053  0.988356      a  two  1.094391  0.999719
# 9      b  two -1.588053  0.988356      a  two  0.149436 -0.454700

# %%
pd.merge(df,df2,how='left')
# Out:
#   col1 col2      col3      col4  col
# 0    a  one  0.008789  0.146322  NaN
# 1    a  two -0.073255  0.831645  NaN
# 2    b  two -1.588053  0.988356  NaN
# 3    a  one -1.411390  0.470098  NaN

# %%
pd.merge(df,df2,how='right')
# Out:
#   col1 col2      col3      col4  col
# 0    b  NaN -1.186421  0.425992  one
# 1    a  NaN  1.094391  0.999719  two
# 2    a  NaN  1.577937  0.521308  one
# 3    b  NaN  0.457513  1.042979  one
# 4    a  NaN  0.149436 -0.454700  two

# %%
pd.merge(df,df2,how='outer')
# Out:
#   col1 col2      col3      col4  col
# 0    a  one  0.008789  0.146322  NaN
# 1    a  two -0.073255  0.831645  NaN
# 2    b  two -1.588053  0.988356  NaN
# 3    a  one -1.411390  0.470098  NaN
# 4    b  NaN -1.186421  0.425992  one
# 5    a  NaN  1.094391  0.999719  two
# 6    a  NaN  1.577937  0.521308  one
# 7    b  NaN  0.457513  1.042979  one
# 8    a  NaN  0.149436 -0.454700  two

# %%
df
# Out:
#   col1 col2      col3      col4
# 0    a  one  0.008789  0.146322
# 1    a  two -0.073255  0.831645
# 2    b  two -1.588053  0.988356
# 3    a  one -1.411390  0.470098

# %% [markdown]
# ##

# %%
df2
# Out:
#   col1  col      col3      col4
# 0    b  one -1.186421  0.425992
# 1    a  two  1.094391  0.999719
# 2    a  one  1.577937  0.521308
# 3    b  one  0.457513  1.042979
# 4    a  two  0.149436 -0.454700

# %%
pd.merge(df,df2,right_index=True,left_index=True)
# Out:
#   col1_x col2    col3_x    col4_x col1_y  col    col3_y    col4_y
# 0      a  one  0.008789  0.146322      b  one -1.186421  0.425992
# 1      a  two -0.073255  0.831645      a  two  1.094391  0.999719
# 2      b  two -1.588053  0.988356      a  one  1.577937  0.521308
# 3      a  one -1.411390  0.470098      b  one  0.457513  1.042979

# %%
df2.columns=['A','B','C','D']

# %%
df.join(df2)
# Out:
#   col1 col2      col3      col4  A    B         C         D
# 0    a  one  0.008789  0.146322  b  one -1.186421  0.425992
# 1    a  two -0.073255  0.831645  a  two  1.094391  0.999719
# 2    b  two -1.588053  0.988356  a  one  1.577937  0.521308
# 3    a  one -1.411390  0.470098  b  one  0.457513  1.042979

# %%
df.stack
